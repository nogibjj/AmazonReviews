# %% [markdown]
# # BERT Real Data Results

# %%
import pandas as pd

real = [
    {
        "Epoch": 1,
        "Training Loss": 0.2507483692318201,
        "Validation Accuracy": 0.9233933333333333,
    },
    {
        "Epoch": 2,
        "Training Loss": 0.14806643503159284,
        "Validation Accuracy": 0.9237933333333332,
    },
    {
        "Epoch": 3,
        "Training Loss": 0.09267619093721732,
        "Validation Accuracy": 0.9209933333333332,
    },
    {"Epoch": 4, "Training Loss": 0.05829818065944128, "Validation Accuracy": 0.9269},
    {"Epoch": 5, "Training Loss": 0.03918841185837518, "Validation Accuracy": 0.9233},
    {
        "Epoch": 6,
        "Training Loss": 0.02931382651287713,
        "Validation Accuracy": 0.9246933333333333,
    },
    {
        "Epoch": 7,
        "Training Loss": 0.024952958113412024,
        "Validation Accuracy": 0.9192933333333333,
    },
    {
        "Epoch": 8,
        "Training Loss": 0.02054100323774037,
        "Validation Accuracy": 0.9214933333333333,
    },
    {
        "Epoch": 9,
        "Training Loss": 0.019715475462644825,
        "Validation Accuracy": 0.9263933333333333,
    },
    {
        "Epoch": 10,
        "Training Loss": 0.01737245107320632,
        "Validation Accuracy": 0.9230933333333332,
    },
    {"Epoch": 11, "Training Loss": 0.015308421369682764, "Validation Accuracy": 0.9261},
    {"Epoch": 12, "Training Loss": 0.014541490527516725, "Validation Accuracy": 0.9206},
    {
        "Epoch": 13,
        "Training Loss": 0.01369464606869733,
        "Validation Accuracy": 0.9229933333333332,
    },
    {
        "Epoch": 14,
        "Training Loss": 0.0124646314116555,
        "Validation Accuracy": 0.9271866666666667,
    },
    {
        "Epoch": 15,
        "Training Loss": 0.01161898533655185,
        "Validation Accuracy": 0.9268866666666666,
    },
    {
        "Epoch": 16,
        "Training Loss": 0.010287173790900488,
        "Validation Accuracy": 0.9233866666666667,
    },
    {
        "Epoch": 17,
        "Training Loss": 0.009877962694518646,
        "Validation Accuracy": 0.9252866666666667,
    },
    {
        "Epoch": 18,
        "Training Loss": 0.01003939304575506,
        "Validation Accuracy": 0.9277799999999999,
    },
    {
        "Epoch": 19,
        "Training Loss": 0.009947417823477371,
        "Validation Accuracy": 0.9240866666666667,
    },
    {
        "Epoch": 20,
        "Training Loss": 0.009799671004540505,
        "Validation Accuracy": 0.9225933333333333,
    },
    {
        "Epoch": 21,
        "Training Loss": 0.009147979067708912,
        "Validation Accuracy": 0.9243933333333333,
    },
    {
        "Epoch": 22,
        "Training Loss": 0.00824640431496664,
        "Validation Accuracy": 0.9262933333333333,
    },
    {
        "Epoch": 23,
        "Training Loss": 0.01018844948242495,
        "Validation Accuracy": 0.9280866666666667,
    },
    {
        "Epoch": 24,
        "Training Loss": 0.008592240310766646,
        "Validation Accuracy": 0.9240866666666667,
    },
    {
        "Epoch": 25,
        "Training Loss": 0.00914196500207654,
        "Validation Accuracy": 0.9240866666666667,
    },
]

real_df = pd.DataFrame(real)

# %%
import matplotlib.pyplot as plt

plt.plot(real_df["Epoch"], real_df["Training Loss"], marker="o")
plt.title("Training Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Training Loss")

plt.show()

# %%
synth = [
    {"Epoch": 1, "Training Loss": 0.3143570843316615, "Validation Accuracy": 0.8915},
    {"Epoch": 2, "Training Loss": 0.21298455553501844, "Validation Accuracy": 0.8896},
    {"Epoch": 3, "Training Loss": 0.15535581326419487, "Validation Accuracy": 0.8911},
    {"Epoch": 4, "Training Loss": 0.09067757285265252, "Validation Accuracy": 0.896},
    {"Epoch": 5, "Training Loss": 0.04910543447086238, "Validation Accuracy": 0.893},
    {"Epoch": 6, "Training Loss": 0.031147130753166857, "Validation Accuracy": 0.8876},
    {"Epoch": 7, "Training Loss": 0.02566207136225712, "Validation Accuracy": 0.8846},
    {"Epoch": 8, "Training Loss": 0.019079924135654437, "Validation Accuracy": 0.8859},
    {"Epoch": 9, "Training Loss": 0.0165781899888967, "Validation Accuracy": 0.8891},
    {"Epoch": 10, "Training Loss": 0.015281018662430507, "Validation Accuracy": 0.8906},
    {"Epoch": 11, "Training Loss": 0.012681439878734454, "Validation Accuracy": 0.8942},
    {"Epoch": 12, "Training Loss": 0.012405454054543952, "Validation Accuracy": 0.8907},
    {"Epoch": 13, "Training Loss": 0.011637112469982457, "Validation Accuracy": 0.8856},
    {"Epoch": 14, "Training Loss": 0.010791900154140603, "Validation Accuracy": 0.8931},
    {"Epoch": 15, "Training Loss": 0.011196299582719803, "Validation Accuracy": 0.893},
    {"Epoch": 16, "Training Loss": 0.010207647942415497, "Validation Accuracy": 0.8889},
    {"Epoch": 17, "Training Loss": 0.008443542164483734, "Validation Accuracy": 0.8915},
    {"Epoch": 18, "Training Loss": 0.009849429667523509, "Validation Accuracy": 0.8882},
    {"Epoch": 19, "Training Loss": 0.008052123070824018, "Validation Accuracy": 0.893},
    {"Epoch": 20, "Training Loss": 0.009664020261597035, "Validation Accuracy": 0.8945},
    {"Epoch": 21, "Training Loss": 0.008384499786765082, "Validation Accuracy": 0.8938},
    {"Epoch": 22, "Training Loss": 0.006561482559356955, "Validation Accuracy": 0.8922},
    {"Epoch": 23, "Training Loss": 0.007230881153660448, "Validation Accuracy": 0.8928},
    {"Epoch": 24, "Training Loss": 0.006851116531034858, "Validation Accuracy": 0.8928},
    {"Epoch": 25, "Training Loss": 0.006851116531034858, "Validation Accuracy": 0.8928},
]

synth_df = pd.DataFrame(synth)

# %%
import matplotlib.pyplot as plt

plt.plot(synth_df["Epoch"], synth_df["Training Loss"], marker="o")
plt.title("Training Loss over Epochs")
plt.xlabel("Epochs")
plt.ylabel("Training Loss")

plt.show()

# %% [markdown]
# # Comparison Plot

# %%
import matplotlib.pyplot as plt

# Assuming synth_df is your DataFrame for synthetic data

fig, axs = plt.subplots(1, 2, figsize=(15, 5))

# Plot for real data
axs[0].plot(real_df["Epoch"], real_df["Training Loss"], marker="o", color="b")
axs[0].set_title("Training Loss from Finetuning BERT using Real Data", weight="bold")
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Training Loss")

# Plot for synthetic data
axs[1].plot(synth_df["Epoch"], synth_df["Training Loss"], marker="o", color="r")
axs[1].set_title(
    "Training Loss from Finetuning BERT using Synthetic Data", weight="bold"
)
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Training Loss")

# Improve aesthetics
fig.tight_layout()
plt.show()
