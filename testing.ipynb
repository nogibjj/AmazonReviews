# %%
#read the synthetic_prob_count.csv file

import pandas as pd

ans = pd.read_csv('synthetic_prob_count.csv')

# %%
#overall, reviewText, sentiment and synthetic_review only

ans = ans[['overall', 'reviewText', 'sentiment', 'synthetic_review']]

print ("synthetic review:")
print(ans['synthetic_review'][40000])
print ("-----")
print ("reviewText:")
print (ans['reviewText'][40000])
# Out:
# synthetic review:
# ...

# %%
ans
# Out:
#        overall                                         reviewText sentiment  \
# 0          5.0  Nice 1/8" to RCA stereo adapter.  Plug phones ...  Positive
# 1          5.0  These headphones deliver amazing sound and cla...  Positive
# 2          5.0  These are very well made tools that come in a ...  Positive
# 3          3.0  Improved our Wi-Fi signal and does what it say...  Positive
# 4          5.0                                 Installed working.  Positive
# ...        ...                                                ...       ...
# 49995      1.0  This item worked for about a  month and a half...  Negative
# 49996      2.0                                  fragil and cheap.  Negative
# 49997      2.0  I got this as free item that came along with r...  Negative
# 49998      1.0  This telescope is being sold as a great scope ...  Negative
# 49999      2.0  This was my third purchase of this Model.  I h...  Negative
#
#                                         synthetic_review
# ...

# %%
#read the synthetic_tfidf.csv file

import pandas as pd

ans = pd.read_csv('synthetic_tfidf.csv')

ans
# Out:
#        Unnamed: 0.1  Unnamed: 0  overall  \
# 0                 0       99615      5.0
# 1                 1      262336      5.0
# 2                 2       35573      5.0
# 3                 3      201016      3.0
# 4                 4      143004      5.0
# ...             ...         ...      ...
# 49995         49995      258089      1.0
# 49996         49996      168870      2.0
# 49997         49997      131074      2.0
# 49998         49998      207362      1.0
# 49999         49999        5671      2.0
#
#                                               reviewText  \
# 0      Nice 1/8" to RCA stereo adapter.  Plug phones ...
# 1      These headphones deliver amazing sound and cla...
# 2      These are very well made tools that come in a ...
# 3      Improved our Wi-Fi signal and does what it say...
# 4                                     Installed working.
# ...                                                  ...
# 49995  This item worked for about a  month and a half...
# ...
